# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Define the RSS feeds
RSS_FEEDS = {
     'Copperbelt Energy': 'https://cecinvestor.com/search/kitwe/feed/rss2/',
     'ZNBC' : 'https://znbc.co.zm/news/search/kitwe/feed/rss2/',
     'News Invasion 24': 'https://newsinvasion24.com/search/kitwe/feed/rss2/',
     'Mwebantu': 'https://www.mwebantu.com/search/kitwe/feed/rss2/',
    'Lusaka Times': 'https://www.lusakatimes.com/search/kitwe/feed/rss2/',
     'Kitwe Online': 'https://kitweonline.com/search/kitwe/feed/rss2/',
     'Daily Revelation Zambia': 'https://dailyrevelationzambia.com/search/kitwe/feed/rss2/',
     'Zambia Monitor': 'https://www.zambiamonitor.com/search/kitwe/feed/rss2/',
     'Tech Africa News': 'https://www.techafricanews.com/search/kitwe/feed/rss2/',
     'Zambian Eye': 'https://zambianeye.com/search/kitwe/feed/rss2/',
     'DailyMail': 'https://www.daily-mail.co.zm/search/kitwe/feed/rss2/'
}

# %%
# Function to handle paginated feed entries
def get_feed_entries(feed_url, pages=10):
    all_entries = []
    for page in range(1, pages + 1):
        paged_url = f"{feed_url}?paged={page}"
        print(f"Fetching page {page} from {feed_url}")
        response = requests.get(paged_url)
        
        if response.status_code != 200:
            print(f"Failed to fetch page {page}: {response.status_code}")
            break
        
        soup = BeautifulSoup(response.content, 'xml')
        items = soup.find_all('item')

        if not items:
            break  # Exit if there are no more entries

        for item in items:
            entry = {
                'title': item.find('title').text if item.find('title') else 'N/A',
                'link': item.find('link').text if item.find('link') else 'N/A',
                'description': item.find('description').text if item.find('description') else 'N/A',
                'pubDate': item.find('pubDate').text if item.find('pubDate') else 'N/A',
                'category': ', '.join([cat.text for cat in item.find_all('category')]) if item.find_all('category') else 'N/A'
            }
            all_entries.append(entry)
    return all_entries

# %%
# Loop through each RSS feed and collect data
all_feed_data = []
for source_name, feed_url in RSS_FEEDS.items():
    entries = get_feed_entries(feed_url, pages=50)
    print(f'RSS Feed done: {source_name}')
    
    # Add source name to each entry
    for entry in entries:
        entry['source'] = source_name
    all_feed_data.extend(entries)

# Create a pandas DataFrame
df = pd.DataFrame(all_feed_data, columns=['source', 'category', 'title', 'link', 'description', 'pubDate'])

# Display the DataFrame
df.head()

# Optional: Save to CSV file
# df.to_csv('rss_feed_data_bs_jupyter.csv', index=False)
# Out:
# Fetching page 1 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 2 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 3 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 4 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 5 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 6 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 7 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 8 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 9 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 10 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 11 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 12 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 13 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 14 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 15 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 16 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 17 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 18 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 19 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 20 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 21 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 22 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Fetching page 23 from https://cecinvestor.com/search/kitwe/feed/rss2/
# Failed to fetch page 23: 404
# RSS Feed done: Copperbelt Energy
# Fetching page 1 from https://znbc.co.zm/news/search/kitwe/feed/rss2/
# Fetching page 2 from https://znbc.co.zm/news/search/kitwe/feed/rss2/
# Fetching page 3 from https://znbc.co.zm/news/search/kitwe/feed/rss2/
# Fetching page 4 from https://znbc.co.zm/news/search/kitwe/feed/rss2/
# Failed to fetch page 4: 404
# RSS Feed done: ZNBC
# Fetching page 1 from https://newsinvasion24.com/search/kitwe/feed/rss2/
# Fetching page 2 from https://newsinvasion24.com/search/kitwe/feed/rss2/
# Fetching page 3 from https://newsinvasion24.com/search/kitwe/feed/rss2/
# Fetching page 4 from https://newsinvasion24.com/search/kitwe/feed/rss2/
# Fetching page 5 from https://newsinvasion24.com/search/kitwe/feed/rss2/
# Fetching page 6 from https://newsinvasion24.com/search/kitwe/feed/rss2/
# Failed to fetch page 6: 404
# RSS Feed done: News Invasion 24
# Fetching page 1 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 2 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 3 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 4 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 5 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 6 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 7 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 8 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 9 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 10 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 11 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 12 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 13 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 14 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 15 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 16 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 17 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 18 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 19 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 20 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 21 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 22 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 23 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 24 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 25 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 26 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 27 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 28 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 29 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 30 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 31 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 32 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 33 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 34 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 35 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 36 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 37 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 38 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 39 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 40 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 41 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 42 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Fetching page 43 from https://www.mwebantu.com/search/kitwe/feed/rss2/
# Failed to fetch page 43: 404
# RSS Feed done: Mwebantu
# Fetching page 1 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 2 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 3 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 4 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 5 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 6 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 7 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 8 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 9 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 10 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 11 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 12 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 13 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 14 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 15 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 16 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 17 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 18 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 19 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 20 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 21 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 22 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 23 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 24 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 25 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 26 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 27 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 28 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 29 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 30 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 31 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 32 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 33 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 34 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 35 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 36 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 37 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 38 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 39 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 40 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 41 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 42 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 43 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 44 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 45 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 46 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 47 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 48 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 49 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# Fetching page 50 from https://www.lusakatimes.com/search/kitwe/feed/rss2/
# RSS Feed done: Lusaka Times
# Fetching page 1 from https://kitweonline.com/search/kitwe/feed/rss2/
# Failed to fetch page 1: 406
# RSS Feed done: Kitwe Online
# Fetching page 1 from https://dailyrevelationzambia.com/search/kitwe/feed/rss2/
# Failed to fetch page 1: 406
# RSS Feed done: Daily Revelation Zambia
# Fetching page 1 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 2 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 3 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 4 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 5 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 6 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 7 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 8 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 9 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 10 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 11 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 12 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 13 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 14 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 15 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 16 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 17 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 18 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 19 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 20 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 21 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 22 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 23 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 24 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 25 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 26 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 27 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 28 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 29 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 30 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 31 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 32 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 33 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Fetching page 34 from https://www.zambiamonitor.com/search/kitwe/feed/rss2/
# Failed to fetch page 34: 404
# RSS Feed done: Zambia Monitor
# Fetching page 1 from https://www.techafricanews.com/search/kitwe/feed/rss2/
# Fetching page 2 from https://www.techafricanews.com/search/kitwe/feed/rss2/
# Failed to fetch page 2: 404
# RSS Feed done: Tech Africa News
# Fetching page 1 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 2 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 3 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 4 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 5 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 6 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 7 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 8 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 9 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 10 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 11 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 12 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 13 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 14 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 15 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 16 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 17 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 18 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 19 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 20 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 21 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 22 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 23 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 24 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 25 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 26 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 27 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 28 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 29 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 30 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 31 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 32 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 33 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 34 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 35 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 36 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 37 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 38 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 39 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 40 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 41 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 42 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 43 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 44 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 45 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 46 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 47 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 48 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 49 from https://zambianeye.com/search/kitwe/feed/rss2/
# Fetching page 50 from https://zambianeye.com/search/kitwe/feed/rss2/
# RSS Feed done: Zambian Eye
# Fetching page 1 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 2 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 3 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 4 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 5 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 6 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 7 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 8 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 9 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 10 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 11 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 12 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 13 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 14 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 15 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 16 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 17 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 18 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 19 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 20 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 21 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 22 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 23 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 24 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 25 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 26 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 27 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 28 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 29 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 30 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 31 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 32 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 33 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 34 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 35 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 36 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 37 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 38 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 39 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 40 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 41 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 42 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 43 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 44 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 45 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 46 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 47 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 48 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 49 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# Fetching page 50 from https://www.daily-mail.co.zm/search/kitwe/feed/rss2/
# RSS Feed done: DailyMail
#               source                  category  \
# 0  Copperbelt Energy  Careers, Current Careers
# 1  Copperbelt Energy  Careers, Current Careers
# 2  Copperbelt Energy  Careers, Current Careers
# 3  Copperbelt Energy  Careers, Current Careers
# 4  Copperbelt Energy  Careers, Current Careers
#
#                                                title  \
# 0    CEC Career Opportunity: Technician – Electrical
# 1  CEC Career Opportunity: Parks & Gardens Assistant
# 2    CEC Career Opportunity: Technician – Mechanical
# 3             CEC Career Opportunity: CAPEX Engineer
# 4           CEC Career Opportunity: Engineer – SCADA
#
#                                                 link  \
# 0  https://cecinvestor.com/cec-career-opportunity...
# 1  https://cecinvestor.com/cec-career-opportunity...
# 2  https://cecinvestor.com/cec-career-opportunity...
# 3  https://cecinvestor.com/cec-career-opportunity...
# 4  https://cecinvestor.com/cec-career-opportunity...
#
#                                          description  \
# 0  We currently have career opportunities in the ...
# 1  We currently have career opportunities in the ...
# 2  We currently have career opportunities in the ...
# 3  We currently have career opportunities in the ...
# 4  We currently have career opportunities in the ...
#
#                            pubDate
# 0  Tue, 24 Sep 2024 09:10:46 +0000
# 1  Tue, 24 Sep 2024 09:09:59 +0000
# 2  Tue, 24 Sep 2024 09:09:22 +0000
# 3  Mon, 23 Sep 2024 15:29:42 +0000
# 4  Mon, 23 Sep 2024 15:29:32 +0000

# %%
#  Save to CSV file
df.to_csv('rss_feed_data_bs_jupyter.csv', index=False)

# %%
df.shape
# Out:
# (2223, 6)
